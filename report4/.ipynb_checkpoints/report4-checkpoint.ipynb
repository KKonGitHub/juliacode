# %%
#問１
using Plots 
using NLsolve

function problem(u)
    return sin(u)-3/4
end


function nls(func, params...; ini = [0.0])
    if typeof(ini) <: Number
        r = nlsolve((vout,vin)->vout[1]=func(vin[1],params...), [ini])
        v = r.zero[1]
    else
        r = nlsolve((vout,vin)->vout .= func(vin,params...), ini)
        v = r.zero
    end
    return v, r.f_converged
end


#二分法

MAX = 100
top = π/2
bottom = 0
err  = 1e-8
solve = 0

for i in 1:MAX
    temp = (bottom + top)/2
    
    if (problem(temp) > 0) 
        top = temp
    elseif (problem(temp) == 0)
        solve = temp
        #たまたま寸分違わぬ解を当てることはほぼ確実にありえないけどないと言い切るのも良くない気がする。
        break
    else
        bottom = temp
    end
    
    if abs(top - bottom) < err
        break
    end
    #所定の誤差以下で離脱。
    
    
    print("下限：$bottom　　上限：$top\n")
end
solve = (bottom + top)/2 

print("近似解：$solve\n")



#ソルバー

sol = nls(problem, ini = 1.0)
print("NLsolveによる解：$sol")
# Out:
# 下限：0.7853981633974483　　上限：1.5707963267948966
# 下限：0.7853981633974483　　上限：1.1780972450961724
# 下限：0.7853981633974483　　上限：0.9817477042468103
# 下限：0.7853981633974483　　上限：0.8835729338221293
# 下限：0.8344855486097889　　上限：0.8835729338221293
# 下限：0.8344855486097889　　上限：0.859029241215959
# 下限：0.8467573949128739　　上限：0.859029241215959
# 下限：0.8467573949128739　　上限：0.8528933180644165
# 下限：0.8467573949128739　　上限：0.8498253564886452
# 下限：0.8467573949128739　　上限：0.8482913757007595
# 下限：0.8475243853068167　　上限：0.8482913757007595
# 下限：0.8479078805037881　　上限：0.8482913757007595
# 下限：0.8479078805037881　　上限：0.8480996281022738
# 下限：0.848003754303031　　上限：0.8480996281022738
# 下限：0.8480516912026523　　上限：0.8480996281022738
# 下限：0.8480516912026523　　上限：0.848075659652463
# 下限：0.8480516912026523　　上限：0.8480636754275577
# 下限：0.848057683315105　　上限：0.8480636754275577
# 下限：0.8480606793713313　　上限：0.8480636754275577
# 下限：0.8480606793713313　　上限：0.8480621773994446
# 下限：0.848061428385388　　上限：0.8480621773994446
# 下限：0.8480618028924163　　上限：0.8480621773994446
# 下限：0.8480619901459304　　上限：0.8480621773994446
# 下限：0.8480619901459304　　上限：0.8480620837726875
# 下限：0.848062036959309　　上限：0.8480620837726875
# 下限：0.8480620603659983　　上限：0.8480620837726875
# 下限：0.8480620720693429　　上限：0.8480620837726875
# 近似解：0.8480620808468514
# NLsolveによる解：(0.848062078981481, true)

# %%
#問２
import Pkg
Pkg.add("NLsolve")
using LinearAlgebra
using Plots
using Nlsolve

function nls(func, params...; ini = [0.0])
    if typeof(ini) <: Number
        r = nlsolve((vout,vin)->vout[1]=func(vin[1],params...), [ini])
        v = r.zero[1]
    else
        r = nlsolve((vout,vin)->vout .= func(vin,params...), ini)
        v = r.zero
    end
    return v, r.f_converged
end


MAX = 100 
#ニュートン法の試行回数上限
err = 1e-7
#ニュートン法の誤差上限


function prob(x,y,z)
    return [
        x+2*y+z+1
        x^2+2*y^2+z^2-10
        sin(x+y+z)-0.7
    ]
end
#解くべき非線形方程式


function probdiv(x,y,z)
    return[
        1 2 1
        2*x 2*y 2*z
        cos(x+y+z) cos(x+y+z) cos(x+y+z)
    ]
end
#上の非線形方程式を微分した行列

#二分法は初期値を決めるのが少し難しそうなので、ニュートン法とNlsolveだけで行く。
ini = [1.0,1.0,1.0]
temp = ini 
solve = 0
for i in 1:MAX
    
    print("$i : 近似値$temp ,誤差$norm(prob(temp))")
    if norm(problem(temp)) < err
        solve = temp
        break
    end
    
    temp = temp - probdiv(temp)\prob(temp)
end

print("近似解:$solve")
# Out:
# ArgumentError: Package Nlsolve not found in current path.
# - Run `import Pkg; Pkg.add("Nlsolve")` to install the Nlsolve package.
#
# Stacktrace:
#  [1] macro expansion
#    @ ./loading.jl:1630 [inlined]
#  [2] macro expansion
#    @ ./lock.jl:267 [inlined]
#  [3] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:1611
